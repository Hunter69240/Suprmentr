# %% [markdown]
# # Machine Learning

# %%
'''
What is ml?
Subset of ai that enables system to learn patterns from data and make predictions/decisions without explicitly programmed

Traditional vs ML:

'''

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#input(hours studied)
X=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([30,40,50,60,70])

# %%
#create model
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#predict
predicted=model.predict([[6]])
print("Predicted marks for 6 hrs is :",predicted)
# Out:
# Predicted marks for 6 hrs is : [80.]

# %%
plt.scatter(X,y)
plt.plot(X,model.predict(X),color="red")
plt.xlabel("Hours")
plt.ylabel("marks")
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
#sample data
X=np.array([[1,2],[2,3],[3,4],[8,7],[9,8],[10,9]])

# %%
kmeans=KMeans(n_clusters=2)

# %%
kmeans.fit(X)
# Out:
# C:\Users\aadis\AppData\Roaming\Python\Python313\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\aadis\AppData\Roaming\Python\Python313\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Program Files\Python313\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python313\Lib\subprocess.py", line 1036, in __init__
# ...

# %%
labels=kmeans.predict(X)

# %%
plt.scatter(X[:,0],X[:,1],c=labels)
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color="red")
plt.show()
