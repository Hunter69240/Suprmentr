# %%
'''
NLP - Natural Language Processing

what is NLP?
it is field of  AI that allows computers to understand , interpret and generate human language .

It combines computer science , artificial intellignece and linguistic and machine learning 


why nlp is important?
Text data is everywhere:

'''

# %%
'''
Process:

Sentence : "Apple released new iphone in 2025"
NLP Task:
* Entity Detection -> apple , iphone, 2025
* Classification -> technology news
*Sentiment -> Neutral

Text Data Challenges:
C1: Ambiguity

C2: Synonyms - different words with same meaning

C3: Noise in text 

C4 : Misspelling

C5 : Slang and Abbreviations:

C6 : Context Understanding

'''

# %%
'''
NLP Pipeline:
Step by step process to convert Raw text to meaningful insights

Text data -> Text CLeaning -> Tokenization -> Stop word removal -> Stemming/Lemmatiozation -> Vectorization -> Machine Learning model -> prediction/Insight
'''

# %%
'''
ex : I absolutely loved the movie!!!

1. Text Cleaning: - Remove Punctuations 
I absolutely loved the movie

2. Tokenization: split sentence into words
['I', 'absolutely', 'loved', 'the', 'movie']

3. Stop word removal : Remove common words such as 'the' , 'is' , 'and' , 'at' , a,an,in
['absolutely', 'loved', 'movie']

4. Stemming/Lemmatization : Convert to root word
loved -> love
playing -> play
running -> run
['absolutely','love', 'movie']

5. Vectorization : Convert words into numbers
I love movie
i love nlp

[i love movie nlp]
 0  1    2     3

love movie
0,1,1,0


'''

# %%
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\aadis\appdata\roaming\python\python313\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\aadis\appdata\roaming\python\python313\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\aadis\appdata\roaming\python\python313\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aadis\appdata\roaming\python\python313\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\aadis\appdata\roaming\python\python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\aadis\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import nltk
#       2 from nltk.tokenize import word_tokenize
#       3 from nltk.corpus import stopwords
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\__init__.py:180
#     177 else:
#     178     from nltk import cluster
# --> 180 from nltk.downloader import download, download_shell
#     182 try:
#     183     import tkinter
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\downloader.py:2475
#    2465             pass
#    2468 ######################################################################
#    2469 # Main:
#    2470 ######################################################################
#    (...)
#    2473
#    2474 # Aliases
# -> 2475 _downloader = Downloader()
#    2476 download = _downloader.download
#    2479 def download_shell():
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\downloader.py:515, in Downloader.__init__(self, server_index_url, download_dir)
#     513 # decide where we're going to save things to.
#     514 if self._download_dir is None:
# --> 515     self._download_dir = self.default_download_dir()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\downloader.py:1068, in Downloader.default_download_dir(self)
#    1064     return
#    1066 # Check if we have sufficient permissions to install in a
#    1067 # variety of system-wide locations.
# -> 1068 for nltkdir in nltk.data.path:
#    1069     if os.path.exists(nltkdir) and nltk.internals.is_writable(nltkdir):
#    1070         return nltkdir
#
# AttributeError: partially initialized module 'nltk' from 'C:\Users\aadis\AppData\Roaming\Python\Python313\site-packages\nltk\__init__.py' has no attribute 'data' (most likely due to a circular import)

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 nltk.download('punkt')
#       2 nltk.download('stopwords')
#
# NameError: name 'nltk' is not defined

# %%
text="I absolutely loved the movie! It was amazing and inspiring."

# %%
text=text.lower()
print(text)
# Out:
# i absolutely loved the movie! it was amazing and inspiring.

# %%
text=text.translate(str.maketrans('','',string.punctuation))
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 text=text.translate(str.maketrans('','',string.punctuation))
#       2 print(text)
#
# NameError: name 'string' is not defined

# %%
tokens=word_tokenize(text)
print(tokens)

# %%
stop_words=set(stopwords.words('english'))
filtered_words=[word for word in tokens if word not in stop_words]
print(filtered_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 stop_words=set(stopwords.words('english'))
#       2 filtered_words=[word for word in tokens if word not in stop_words]
#       3 print(filtered_words)
#
# NameError: name 'stopwords' is not defined

# %%
stemmer=PorterStemmer()
stemmed_words=[stemmer.stem(word) for word in filtered_words]
print(stemmed_words)
