# %%
'''
NLP - Natural Language Processing

what is NLP?
it is field of  AI that allows computers to understand , interpret and generate human language .

It combines computer science , artificial intellignece and linguistic and machine learning 


why nlp is important?
Text data is everywhere:

'''
# Out:
# '\nNLP - Natural Language Processing\n\nwhat is NLP?\nit is field of  AI that allows computers to understand , interpret and generate human language .\n\nIt combines computer science , artificial intellignece and linguistic and machine learning \n\n\nwhy nlp is important?\nText data is everywhere:\n\n'

# %%
'''
Process:

Sentence : "Apple released new iphone in 2025"
NLP Task:
* Entity Detection -> apple , iphone, 2025
* Classification -> technology news
*Sentiment -> Neutral

Text Data Challenges:
C1: Ambiguity

C2: Synonyms - different words with same meaning

C3: Noise in text 

C4 : Misspelling

C5 : Slang and Abbreviations:

C6 : Context Understanding

'''
# Out:
# '\nProcess:\n\nSentence : "Apple released new iphone in 2025"\nNLP Task:\n* Entity Detection -> apple , iphone, 2025\n* Classification -> technology news\n*Sentiment -> Neutral\n\nText Data Challenges:\nC1: Ambiguity\n\nC2: Synonyms - different words with same meaning\n\nC3: Noise in text \n\nC4 : Misspelling\n\nC5 : Slang and Abbreviations:\n\nC6 : Context Understanding\n\n'

# %%
'''
NLP Pipeline:
Step by step process to convert Raw text to meaningful insights

Text data -> Text CLeaning -> Tokenization -> Stop word removal -> Stemming/Lemmatiozation -> Vectorization -> Machine Learning model -> prediction/Insight
'''
# Out:
# '\nNLP Pipeline:\nStep by step process to convert Raw text to meaningful insights\n\nText data -> Text CLeaning -> Tokenization -> Stop word removal -> Stemming/Lemmatiozation -> Vectorization -> Machine Learning model -> prediction/Insight\n'

# %%
'''
ex : I absolutely loved the movie!!!

1. Text Cleaning: - Remove Punctuations 
I absolutely loved the movie

2. Tokenization: split sentence into words
['I', 'absolutely', 'loved', 'the', 'movie']

3. Stop word removal : Remove common words such as 'the' , 'is' , 'and' , 'at' , a,an,in
['absolutely', 'loved', 'movie']

4. Stemming/Lemmatization : Convert to root word
loved -> love
playing -> play
running -> run
['absolutely','love', 'movie']

5. Vectorization : Convert words into numbers
I love movie
i love nlp

[i love movie nlp]
 0  1    2     3

love movie
0,1,1,0


'''
# Out:
# "\nex : I absolutely loved the movie!!!\n\n1. Text Cleaning: - Remove Punctuations \nI absolutely loved the movie\n\n2. Tokenization: split sentence into words\n['I', 'absolutely', 'loved', 'the', 'movie']\n\n3. Stop word removal : Remove common words such as 'the' , 'is' , 'and' , 'at' , a,an,in\n['absolutely', 'loved', 'movie']\n\n4. Stemming/Lemmatization : Convert to root word\nloved -> love\nplaying -> play\nrunning -> run\n['absolutely','love', 'movie']\n\n5. Vectorization : Convert words into numbers\nI love movie\ni love nlp\n\n[i love movie nlp]\n 0  1    2     3\n\nlove movie\n0,1,1,0\n\n\n"

# %%
# Optional dependency install (not required for this notebook now)
# %pip install nltk

# %%
# %pip uninstall nltk -y
# %pip install "nltk==3.9.1"
# Out:
# Found existing installation: nltk 3.9.1
# Uninstalling nltk-3.9.1:
#   Successfully uninstalled nltk-3.9.1
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aadis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aadis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aadis\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
text="I absolutely loved the movie! It was amazing and inspiring."

# %%
text=text.lower()
print("Lowercase:", text)
# Out:
# Lowercase: i absolutely loved the movie! it was amazing and inspiring.

# %%
text=text.translate(str.maketrans('','',string.punctuation))
print(text)
# Out:
# i absolutely loved the movie it was amazing and inspiring

# %%
tokens=word_tokenize(text)
print(tokens)
# Out:
# ['i', 'absolutely', 'loved', 'the', 'movie', 'it', 'was', 'amazing', 'and', 'inspiring']

# %%
stop_words=set(stopwords.words('english'))
filtered_words=[word for word in tokens if word not in stop_words]
print(filtered_words)
# Out:
# ['absolutely', 'loved', 'movie', 'amazing', 'inspiring']

# %%
stemmer=PorterStemmer()
stemmed_words=[stemmer.stem(word) for word in filtered_words]
print(stemmed_words)
# Out:
# ['absolut', 'love', 'movi', 'amaz', 'inspir']
