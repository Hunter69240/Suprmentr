# %%
'''
Prompt engineering , Prompt design , LLM API
'''

# %%
'''
What is prompt engineering?
Designing inputs to get desired output from LLMs

LLM Flow:
user input -> tokenization -> transformers -> prediction -> output


prompt structure:
role + task + context + format + constraints

types of prompting :
1 . Zero shot prompting  : "translate hello to french" no examples
2. Few Shot prompting : "English: Hello -> french "
                        "English : thank you -> french"
                        models learns the pattern
3. Chain of thoughts : forces reasoning
solve step by step : what is 25*4+10
4. Role based prompting : you are a senior developer. 
                            Review the code: ....
5. Instruction based prompting : constraints
Summarize the chapter in bullet points.
'''

# %%
'''
bad vs good prompting:

bad prompt              Good prompt
explain LLM's            Explain LLM's with examples  and  usecase studies 
write code               write code on nodejs , api with examples for login using tokens
'''
