# %%
'''
Cv is a field of ai that enables machines to see and interpret images , pdfs, like humans

examples:
face unlock , self driving cars , medical imaging , object detection 

how it works:
image -> preprocessing -> feature extraction -> model-> prediction 

image representaion and pixels
image = matrix of pixel values

types :
1. grayscale image value = 0-255 (0=black , 255=white)
2.color image (RGB):3channels - RED,BLUE,GREEN
each pixel :[R,G,B]
'''

# %%
import cv2

image=cv2.imread('ANGEL AND DEVIL.png') 

#print shape
print(image.shape) # (height, width, channels)

#resolution - width x height
#more pixels -> better quality
# Out:
# (2160, 3840, 3)

# %%
'''
OpenCV = open source computer vision library
used for image processing , video analysis , object detection
'''

# %%
#read and display image
import cv2
img=cv2.imread('ANGEL AND DEVIL.png')
cv2.imshow('Image',img)
cv2.waitKey(0) # wait for key press
cv2.destroyAllWindows() # close all windows
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 4
#       2 import cv2
#       3 img=cv2.imread('ANGEL AND DEVIL.png')
# ----> 4 cv2.imshow('Image',img)
#       5 cv2.waitKey(0) # wait for key press
#       6 cv2.destroyAllWindows() # close all windows
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
#convert to grayscale
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow('Grayscale Image',gray)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 3
#       1 #convert to grayscale
#       2 gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# ----> 3 cv2.imshow('Grayscale Image',gray)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
#resize image
resized=cv2.resize(img,(300,300)) # width , height

# %%
#draw rectangle
cv2.rectangle(img,(50,50),(200,200),(0,255,0),2) # image , top left , bottom right , color , thickness
# Out:
# array([[[37, 30, 30],
#         [37, 30, 29],
#         [36, 30, 29],
#         ...,
#         [46, 52, 54],
#         [46, 52, 54],
#         [46, 52, 54]],
#
#        [[36, 30, 27],
#         [37, 30, 27],
#         [36, 30, 27],
#         ...,
#         [46, 51, 50],
#         [46, 51, 50],
#         [46, 51, 50]],
#
#        [[35, 30, 27],
#         [35, 30, 27],
#         [35, 30, 27],
#         ...,
#         [46, 51, 50],
#         [46, 51, 50],
#         [46, 51, 50]],
#
#        ...,
#
#        [[52, 41, 37],
#         [52, 41, 37],
#         [52, 41, 37],
#         ...,
#         [57, 63, 61],
#         [55, 60, 59],
#         [56, 61, 60]],
#
#        [[52, 41, 37],
#         [52, 41, 37],
#         [53, 41, 36],
#         ...,
#         [56, 61, 60],
#         [56, 61, 60],
#         [56, 61, 60]],
#
#        [[52, 41, 38],
#         [52, 41, 37],
#         [52, 41, 37],
#         ...,
#         [55, 60, 59],
#         [56, 61, 60],
#         [55, 58, 59]]], dtype=uint8)

# %%
'''
1. Blurring (noise removal )
used for removing noise and smoothening image

2.Edge Detection
detect boundaries of object

3.Threshold
Convert image to black and white
'''

# %%
import cv2
img=cv2.imread('ANGEL AND DEVIL.png')
blur=cv2.GaussianBlur(img,(5,5),0) # image , kernel size , sigma

# %%
edges=cv2.Canny(img,100,200) # image , lower threshold , upper threshold

# %%
_ , thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY) # image , threshold value , max value , threshold type

# %%
import cv2
img=cv2.imread('ANGEL AND DEVIL.png')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blur=cv2.GaussianBlur(gray,(5,5),0)
edges=cv2.Canny(blur,100,200)

cv2.imshow('Edges',edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 7
#       4 blur=cv2.GaussianBlur(gray,(5,5),0)
#       5 edges=cv2.Canny(blur,100,200)
# ----> 7 cv2.imshow('Edges',edges)
#       8 cv2.waitKey(0)
#       9 cv2.destroyAllWindows()
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
