# %%
'''
what is cloud computing?

cloud=access computing resources  over internet  instead of local machine
ex: instead of running ml model on laptop -> deploy online -> users can access via url

benefits:
scalability
cost efficient
availability
no hardware needed

real life examples:
google drive
netflix
AWS
'''

# %%
'''
Cloud service models:
1.IAAS : Infrastructure as a Service (u control everything)

2. PAAS : Platform as a Service (u deplot code , platform handle infrastructure)

3.SAAS : Software as a Service (u use software hosted on cloud, no control over infrastructure or platform)
'''

# %%
'''
AI architecture in cloud:
 flow of AI app
 user -> frontend -> backend api  -> ml model -> prediction -> response


'''
